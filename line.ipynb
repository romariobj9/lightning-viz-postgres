# %% [markdown]
# # <img style='float: left' src="http://lightning-viz.github.io/images/logo.png"> <br> <br> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Line plots in <a href='http://lightning-viz.github.io/'><font color='#9175f0'>Lightning</font></a>

# %% [markdown]
# ## <hr> Configurar

# %%
from lightning import Lightning

from numpy import random, asarray, arange

from scipy.ndimage.filters import gaussian_filter
from seaborn import color_palette

# %% [markdown]
# ## Conexion al Servidor

# %%
lgn = Lightning(ipython=True)
# Out:
# <div style='margin-top:8px'><img src='data:image/png;base64,...' width='30px' height='35px' style='display: inline-block; padding-right: 10px'></img><span>Lightning initialized</span></div>
# Connected to server at http://localhost:3000

# %% [markdown]
# ## <hr> Una de las líneas al azar con estilos predeterminados

# %% [markdown]
# Comportamientos de zoom personalizados

# %%
y = gaussian_filter(random.rand(100), 3)
lgn.line(y)
# Out:
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7; IE=EDGE"/><meta charset="UTF-8"/><link href="//fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet" type="text/css"/><link rel="stylesheet" href="http://localhost:3000/css/app.css"/><div id="lightning-body" class="container content wrap push"><div class="feed-container"><div data-model="visualization" data-model-id="61660f24-4be0-477c-b878-36619ac23e39" class="feed-item-container"><div data-type="lightning-line" data-data="{&quot;series&quot;:[0.5488116120582426,0.556417982027781,0.5713914284417156,0.5924148140427884,0.6162423618092667,0.6381303072833426,0.6536078492084515,0.6607334019446991,0.6611385863989891,0.6586979879140341,0.656761164862542,0.6558094763231623,0.6535463475872044,0.6472102328638977,0.6365910599965514,0.6251115659013244,0.6180286772374253,0.6187427798072631,0.6256304552725522,0.6318012500591991,0.6279045817591684,0.606573265101504,0.5657791210104669,0.5095735145732103,0.44622451289109194,0.38490989771027373,0.33328364041439773,0.29638488987323497,0.27706828780865733,0.2766771133298641,0.294996275171364,0.3295666789252098,0.37490693051171714,0.42304673215799626,0.4655212792977563,0.49602391605653995,0.5123603337728313,0.5166507263519067,0.5141886718826539,0.5114955081393511,0.514634437022068,0.5277247897416019,0.5518480539277104,0.5841687776514817,0.6178067325039851,0.6431081239300711,0.6503939026127924,0.6335668276208454,0.5930458496533617,0.5365042540333945,0.4769228681876391,0.4283504203919075,0.4014034612662354,0.3998854592497769,0.41970548810977415,0.45037833186737164,0.47850589719718384,0.4925167807925205,0.4866577947896597,0.46282557259758095,0.4292559358936675,0.3969387249413229,0.375628547625031,0.37096988207372517,0.3835177451244686,0.4092851015284553,0.44126469419175224,0.47159006227612577,0.4939167682707128,0.5053584889663858,0.5070380514041365,0.502861773076431,0.49710557551725804,0.4920948808881254,0.4875074512703318,0.48151282602925294,0.4730823980525548,0.46366205297720775,0.45694999767097444,0.45694996462454435,0.46558177221513697,0.48172226719745903,0.502136676631878,0.5236481382985568,0.5447424822554706,0.565502485232199,0.586103984895747,0.6050606997248378,0.6188850978093312,0.6234276980209371,0.6161295485136078,0.597810262703196,0.5727456378795,0.5473340850965407,0.5278412518155413,0.5183563322092578,0.5195139139237146,0.5283036339602509,0.539253250708324,0.5465677836409623]}" data-images="[]" data-options="{&quot;width&quot;:600,&quot;zoom&quot;:true,&quot;description&quot;:null,&quot;height&quot;:null}" id="viz-61660f24-4be0-477c-b878-36619ac23e39" data-initialized="false" class="feed-item"></div></div></div></div><script>window.lightning = window.lightning || {};
# window.lightning.host = "http://localhost:3000/" || 'http://127.0.0.1:3000/';
# window.lightning.vizCount = (window.lightning.vizCount + 1) || 1;
# window.lightning.requiredVizTypes = window.lightning.requiredVizTypes || [];
# if(window.lightning.requiredVizTypes.indexOf("line") === -1) {
#     window.lightning.requiredVizTypes.push("line");
# }
# window._require = window.require;
# window.require = undefined;
# window._define = window.define;
# window.define = undefined;</script><script src="http://localhost:3000/js/embed.js"></script>

# %% [markdown]
# ## <hr>Establecimiento del ancho de línea y el color

# %% [markdown]
# Por una linea puedes poner tamaño y color

# %%
y = gaussian_filter(random.rand(100), 3)
lgn.line(y, thickness=10, color=[255,100,100])
# Out:
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7; IE=EDGE"/><meta charset="UTF-8"/><link href="//fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet" type="text/css"/><link rel="stylesheet" href="http://localhost:3000/css/app.css"/><div id="lightning-body" class="container content wrap push"><div class="feed-container"><div data-model="visualization" data-model-id="6038e032-6a03-4b68-a66a-69fb4622d93d" class="feed-item-container"><div data-type="lightning-line" data-data="{&quot;color&quot;:[[255,100,100]],&quot;series&quot;:[0.3557545294801245,0.35990797835173227,0.3691294144884145,0.38416607728875757,0.4042099020600973,0.4264996863353652,0.4472844816623225,0.46339820480211336,0.4736313573880756,0.4783764320873609,0.4785109409544038,0.4744101419353681,0.4661549441920847,0.4547673066018575,0.4430269853164114,0.434871093961056,0.4335391197271785,0.4399175682361234,0.45202347838043,0.46591178186357574,0.47707236636291844,0.48166562624188863,0.47713006956623316,0.46237579554314434,0.437934643745994,0.40580459396678314,0.36933958485070795,0.33270422392523025,0.300272640880601,0.27585762454341106,0.26186315488096396,0.25880385898085523,0.2652611157547089,0.27822159382067124,0.29378415078038317,0.3081732027519285,0.3189489728862692,0.32599552808172727,0.33134839204097877,0.33770178416494645,0.34633570887169085,0.35598350508062365,0.3634494694790048,0.3656969453685475,0.36217083949172224,0.3557490111838339,0.3520935066069126,0.35733638543334567,0.3753754686852981,0.40606317261584624,0.44517104019784537,0.4860473745312649,0.5222792738000788,0.5497987346457096,0.5676103879021086,0.5771248733427352,0.5803871181950634,0.5786955270795571,0.5720619344824216,0.5599952373601644,0.5427922294014569,0.5225515367849183,0.502826317635965,0.48704126300860906,0.47681714751934545,0.47160136635114996,0.4697257497316932,0.46989575630889047,0.4717876073427331,0.4751605323295998,0.47910319854132294,0.482135272871808,0.4834294310264069,0.48378361493989186,0.4854674221269209,0.4911687238958458,0.5027089859873107,0.5200040142960882,0.540519440756716,0.5594285879288079,0.5708388628324265,0.5702682795150332,0.556850213076352,0.5339044927221224,0.5068930592250438,0.48023056993407776,0.4553501217619105,0.43140357907729965,0.4080295988789152,0.38762609357464367,0.3752222908983004,0.37617365161220456,0.3927876353449613,0.42214481429661127,0.4565768239403888,0.4865445735618589,0.5049401173864645,0.5103003203398463,0.5071498295537571,0.502852195116572],&quot;thickness&quot;:[10]}" data-images="[]" data-options="{&quot;width&quot;:600,&quot;zoom&quot;:true,&quot;description&quot;:null,&quot;height&quot;:null}" id="viz-6038e032-6a03-4b68-a66a-69fb4622d93d" data-initialized="false" class="feed-item"></div></div></div></div><script>window.lightning = window.lightning || {};
# window.lightning.host = "http://localhost:3000/" || 'http://127.0.0.1:3000/';
# window.lightning.vizCount = (window.lightning.vizCount + 1) || 1;
# window.lightning.requiredVizTypes = window.lightning.requiredVizTypes || [];
# if(window.lightning.requiredVizTypes.indexOf("line") === -1) {
#     window.lightning.requiredVizTypes.push("line");
# }
# window._require = window.require;
# window.require = undefined;
# window._define = window.define;
# window.define = undefined;</script><script src="http://localhost:3000/js/embed.js"></script>

# %% [markdown]
# ## <hr> Multiples lineas

# %% [markdown]
# Se asignará automáticamente a los colores de múltiples líneas .

# %%
y = gaussian_filter(random.rand(5,100), [0, 3])
y = (y.T + arange(0,5)*0.2).T
lgn.line(y, thickness=6)
# Out:
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7; IE=EDGE"/><meta charset="UTF-8"/><link href="//fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet" type="text/css"/><link rel="stylesheet" href="http://localhost:3000/css/app.css"/><div id="lightning-body" class="container content wrap push"><div class="feed-container"><div data-model="visualization" data-model-id="f2913d1d-f4c9-418c-95a5-22c2f1ed66b4" class="feed-item-container"><div data-type="lightning-line" data-data="{&quot;series&quot;:[[0.5279645608114045,0.5140288175584522,0.4912687617893049,0.46724421764462026,0.44854777049253775,0.4383716783715708,0.43621209713944653,0.4393151360165387,0.4444002618190407,0.44896648662093963,0.45175536146962225,0.45292279817224945,0.45372754858933806,0.4556212761744143,0.4587265769317481,0.46074420869094906,0.45723679036148057,0.44383448311007173,0.41914684889122733,0.3866936574643406,0.3543657002344781,0.3315051739922622,0.3251372968962314,0.3374376657517563,0.3655543743182271,0.4036238432531729,0.44538403783795877,0.48603940399929035,0.5228429599258233,0.5545816522385736,0.5810464237079261,0.6025426609168576,0.6194104243723565,0.6314604923486435,0.6377760652930669,0.6372736116107351,0.6301136508149097,0.618847081098673,0.6080284934527176,0.6021777793250174,0.6031034714232288,0.6086833298454892,0.6138265472107308,0.6130885741019548,0.6031094542404424,0.5836247437030329,0.5567029852247423,0.5250368178593048,0.4903912261109908,0.4532843575964539,0.41388448818583135,0.3735362275282396,0.3354371197546523,0.3040570427764828,0.2836208232625571,0.2767535185465262,0.2841907451247516,0.3052281497543256,0.33839584590769,0.3815451466033351,0.4315934248195411,0.48394304590821496,0.5322972009825329,0.5692627746551393,0.5880242505853503,0.5849856921003143,0.5619408817366467,0.5263031792301136,0.48858244901140313,0.45839779552792764,0.44122451115248507,0.437523487629725,0.44428249098806893,0.4573300595875222,0.4728685534917391,0.4880970348634927,0.5013334872327879,0.5122220334974519,0.5216374281816057,0.5311556847438679,0.5423674138698599,0
251173107,0.5241715710048593,0.5233977973332546,0.5237282873553979,0.5253121864511252,0.5282043213504164,0.532441747175234,0.5380061680865837,0.5448902859419283,0.5530895663896659,0.5625042376857887,0.5729557875512818,0.5841112747929597,0.5955149337350121,0.6065376066647903,0.6165255605121315,0.6248396955615435,0.6308968467077696,0.6342639530910691,0.6346617681350388,0.6319573491245297,0.6262020785187068,0.6175288610922863,0.6062415001659702,0.5927172540234247,0.5774649936049113,0.5611444793428512,0.5445210136686276,0.5284660021348522,0.5138489014650746,0.5015016409333173,0 ...
# window.lightning.host = "http://localhost:3000/" || 'http://127.0.0.1:3000/';
# window.lightning.vizCount = (window.lightning.vizCount + 1) || 1;
# window.lightning.requiredVizTypes = window.lightning.requiredVizTypes || [];
# if(window.lightning.requiredVizTypes.indexOf("line") === -1) {
#     window.lightning.requiredVizTypes.push("line");
# }
# window._require = window.require;
# window.require = undefined;
# window._define = window.define;
# window.define = undefined;</script><script src="http://localhost:3000/js/embed.js"></script>

# %% [markdown]
# ## <hr> Series Agrupadas con etiquetas

# %% [markdown]
# En lugar de especificar directamente los colores como RGB , puede especificar las asignaciones de grupo .
# <br>
# Aquí usamos ` scikitlearn` para generar clusters y luego de color acuerdo con la etiqueta clúster

# %%
d, g = datasets.make_blobs(n_features=5, n_samples=20, centers=5, cluster_std=1.0, random_state=100)
lgn.line(d, group=g)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-939078c4cbac> in <module>()
# ----> 1 d, g = datasets.make_blobs(n_features=5, n_samples=20, centers=5, cluster_std=1.0, random_state=100)
#       2 lgn.line(d, group=g)
#
# NameError: name 'datasets' is not defined

# %% [markdown]
# ## <hr> Etiquetas Axis

# %% [markdown]
# También puede etiquetar los ejes .

# %%
y = gaussian_filter(random.rand(100), 3)
lgn.line(y, thickness=10, xaxis='variable #1', yaxis='variable #2')
# Out:
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7; IE=EDGE"/><meta charset="UTF-8"/><link href="//fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet" type="text/css"/><link rel="stylesheet" href="http://localhost:3000/css/app.css"/><div id="lightning-body" class="container content wrap push"><div class="feed-container"><div data-model="visualization" data-model-id="38c61f61-0bcf-41a8-a052-ccf954da905a" class="feed-item-container"><div data-type="lightning-line" data-data="{&quot;series&quot;:[0.5988898056934712,0.5931777241250135,0.5789406532926673,0.5534234030643452,0.5174232546198884,0.47693887843348637,0.4415941517706617,0.4207213688433746,0.419563659959441,0.4375227975954823,0.46920999933702157,0.5073983302660834,0.5457884810739309,0.5800361307366284,0.6068795819178687,0.6226927034790054,0.6234862584766308,0.6067725786962614,0.5740302912381228,0.5316752174712507,0.4894138469025504,0.45665573434868595,0.43920224710060274,0.4379628299087871,0.44992318157861577,0.4705548027539276,0.49588417202571033,0.5234936143417792,0.5522796758813805,0.5817057702263047,0.6110233979754611,0.639088554209597,0.6646416920209286,0.6865475932630621,0.7038471072541154,0.715388349822212,0.7197134882182228,0.7156752911514892,0.7032981321974435,0.6843368189622439,0.6617264718516849,0.6383633999009355,0.6163189834368723,0.5969200258583945,0.5810622502048335,0.569127425039258,0.5602217520757292,0.5516468476495634,0.5395550995264031,0.5207034308055641,0.49419780228205834,0.46253361702055784,0.43105184718272616,0.4065434019492732,0.39507685002976506,0.4000762356725462,0.4211691581957354,0.4541397760902226,0.4919899200987832,0.526537031385354,0.5503860255150275,0.5587345569933149,0.5505606958963125,0.5287393094641769,0.4987141437913726,0.4663402293331839,0.43584078907188034,0.4086388402086302,0.3839606762290739,0.36069029924867485,0.33947534549640807,0.3236337032461767,0.31793639760835873,0.3257956289414111,0.3467798295482014,0.3762406673557941,0.40737674245391187,0.4345147332698319,0.45491094737665944,0.4684477887555998,0.4754133638812174,0.4747433755414145,0.46446951086953375,0.44427047656184193,0.41784338245650016,0.39260982131226185,0.37658520203849566,0.3742259777942948,0.38428424349358004,0.40086164096667615,0.41671838868241295,0.4261992697861,0.42651433722386345,0.41713473382869937,0.39876901746341414,0.372866559344387,0.3420162424707084,0.31054959528804005,0.2843419260462575,0.2693202876623403],&quot;thickness&quot;:[10],&quot;xaxis&quot;:[&quot;variable #1&quot;],&quot;yaxis&quot;:[&quot;variable #2&quot;]}" data-images="[]" data-options="{&quot;width&quot;:600,&quot;zoom&quot;:true,&quot;description&quot;:null,&quot;height&quot;:null}" id="viz-38c61f61-0bcf-41a8-a052-ccf954da905a" data-initialized="false" class="feed-item"></div></div></div></div><script>window.lightning = window.lightning || {};
# window.lightning.host = "http://localhost:3000/" || 'http://127.0.0.1:3000/';
# window.lightning.vizCount = (window.lightning.vizCount + 1) || 1;
# window.lightning.requiredVizTypes = window.lightning.requiredVizTypes || [];
# if(window.lightning.requiredVizTypes.indexOf("line") === -1) {
#     window.lightning.requiredVizTypes.push("line");
# }
# window._require = window.require;
# window.require = undefined;
# window._define = window.define;
# window.define = undefined;</script><script src="http://localhost:3000/js/embed.js"></script>

# %% [markdown]
# ## Ejemplo Line con datos extraidos de una base de datos

# %%
import psycopg2, psycopg2.extras
try:
    conn = psycopg2.connect("dbname='gp' user='roma' host='localhost' password='roma'")
except:
    print "I am unable to connect to the database"
cur = conn.cursor()

# %%
cur.execute("""SELECT cantidad,nomempresa from produccion inner join empresas on produccion.idempresa=empresas.idempresa where empresas.idempresa=1 and idsubtipo=1""")
rows = cur.fetchall()
i=1
x=[]
y=[]
for row in rows:
    x.append(i)
    i=i+1
    y.append(int(row[0]))

# %% [markdown]
# # Energia Hidraulica Producida por la empresa CELEC-Electroguayas

# %% [markdown]
# <br>
# El eje X consta por el año desde el 2000 hasta el 2014 de los años producidos por la empresa CELEC-Electroguayas y en el eje Y consta la cantidad de produccion generada en GW

# %%
lgn.line(y, thickness=5, xaxis='Celec-Electroguayas', yaxis='Produccion en GW')
# Out:
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7; IE=EDGE"/><meta charset="UTF-8"/><link href="//fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet" type="text/css"/><link rel="stylesheet" href="http://localhost:3000/css/app.css"/><div id="lightning-body" class="container content wrap push"><div class="feed-container"><div data-model="visualization" data-model-id="c86567f1-782d-4741-9716-4f54fe072236" class="feed-item-container"><div data-type="lightning-line" data-data="{&quot;series&quot;:[5132,134324,39,68971,2847,15,2611,539038,1,2412,94,1374,52950,1,22195],&quot;thickness&quot;:[5],&quot;xaxis&quot;:[&quot;Celec-Electroguayas&quot;],&quot;yaxis&quot;:[&quot;Produccion en GW&quot;]}" data-images="[]" data-options="{&quot;width&quot;:600,&quot;zoom&quot;:true,&quot;description&quot;:null,&quot;height&quot;:null}" id="viz-c86567f1-782d-4741-9716-4f54fe072236" data-initialized="false" class="feed-item"></div></div></div></div><script>window.lightning = window.lightning || {};
# window.lightning.host = "http://localhost:3000/" || 'http://127.0.0.1:3000/';
# window.lightning.vizCount = (window.lightning.vizCount + 1) || 1;
# window.lightning.requiredVizTypes = window.lightning.requiredVizTypes || [];
# if(window.lightning.requiredVizTypes.indexOf("line") === -1) {
#     window.lightning.requiredVizTypes.push("line");
# }
# window._require = window.require;
# window.require = undefined;
# window._define = window.define;
# window.define = undefined;</script><script src="http://localhost:3000/js/embed.js"></script>

# %% [markdown]
# # La siguiente Grafica muestra los mismos valores pero de cada una de las 34 empresas

# %%
cur.execute("""SELECT cantidad,nomempresa from produccion inner join empresas on produccion.idempresa=empresas.idempresa where anio=2004""")
rows = cur.fetchall()
i=0
x=[]
y=[]
for row in rows:
    i=i+1
    x.append(int(row[0]))
    if i == 10:
        y.append(x)
        del x
        x=[]
        i=0

# %%
lgn.line(y, thickness=4, xaxis='Tipos De Generadores de Energia', yaxis='Produccion en GW')
# Out:
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7; IE=EDGE"/><meta charset="UTF-8"/><link href="//fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet" type="text/css"/><link rel="stylesheet" href="http://localhost:3000/css/app.css"/><div id="lightning-body" class="container content wrap push"><div class="feed-container"><div data-model="visualization" data-model-id="e65c01cf-ff8c-4003-8c06-cbd1edef651d" class="feed-item-container"><div data-type="lightning-line" data-data="{&quot;series&quot;:[[2847,15,2431,514042,7,2451,87,1361,49637,69],[20483,1843,2917,177021,1,8112,1,647,2171,101089],[79,13967,915,3,2857,254285,15,7124,538,1318],[86225,0,15527,4,148,2868,262795,29,15631,176],[3,1693,115159,16,7196,335,1,1216,94171,1],[17636,248,3,2026,130437,1,9157,651,2437,53948],[22,21621,6422,3,4400,184805,1,1972,410,521],[28870,31,25523,4,6531,4184,272764,1,6480,4552],[2,2106,91807,15,1307,152,312,6843,14,19570],[5,3280,3663,178499,0,112672,14309,11,4696,746262],[1,15469,823,2801,131620,26,14562,1,1702,5408],[140739,44,70656,2846,15,2461,516332,7,2465,88],[1361,49857,70,20531,1859,2947,177573,1,7971,1],[586,2037,101930,79,14069,3,923,2879,256131,15],[7138,540,1318,86296,0,15680,4,145,2911,266335],[29,15581,3,176,1615,115976,16,7348,1,336],[1218,94272,1,17751,3,247,2030,130791,1,9246],[657,2454,54517,22,21802,6454,3,4410,185133,1],[1974,411,520,28875,31,26424,6583,4,4229,273719],[1,6532,4562,2,2106,92027,15,1306,151,313],[6881,14,19650,3303,6,3651,179202,0,113595,11],[14361,4706,749822,1,15539,828,2813,131976,26,14675],[1,1703,5414,141394,44,71096,15,2848,2495,519762],[7,2406,94,1371,50197,70,20668,1876,2976,178261],[1,8247,645,1,2188,102870,80,14148,3,927],[2894,257569,13,7147,541,1343,87138,0,15863,143],[4,2949,270123,29,15578,3,176,1606,116327,5],[7389,1,334,1228,94454,1,17995,3,247,2037],[131382,1,9272,663,2300,54654,22,21676,3,6473],[4411,185727,1,2035,416,533,29065,31,26519,6602],[4,4144,274511,1,6571,4571,2,2112,92271,15],[1306,157,313,6901,14,19724,6,3317,3655,179805],[0,114134,14424,11,4711,752290,1,15577,834,2825],[132385,26,1,14756,1699,5427,141955,44,71575,2850]],&quot;thickness&quot;:[4],&quot;xaxis&quot;:[&quot;Tipos De Generadores de Energia&quot;],&quot;yaxis&quot;:[&quot;Produccion en GW&quot;]}" data-images="[]" data-options="{&quot;width&quot;:600,&quot;zoom&quot;:true,&quot;description&quot;:null,&quot;height&quot;:null}" id="viz-e65c01cf-ff8c-4003-8c06-cbd1edef651d" data-initialized="false" class="feed-item"></div></div></div></div><script>window.lightning = window.lightning || {};
# window.lightning.host = "http://localhost:3000/" || 'http://127.0.0.1:3000/';
# window.lightning.vizCount = (window.lightning.vizCount + 1) || 1;
# window.lightning.requiredVizTypes = window.lightning.requiredVizTypes || [];
# if(window.lightning.requiredVizTypes.indexOf("line") === -1) {
#     window.lightning.requiredVizTypes.push("line");
# }
# window._require = window.require;
# window.require = undefined;
# window._define = window.define;
# window.define = undefined;</script><script src="http://localhost:3000/js/embed.js"></script>

# %%
for a in range(1,5):
    i=1
    x=[]
    y=[]
    cur.execute("""SELECT cantidad,nomempresa from produccion inner join empresas on produccion.idempresa=empresas.idempresa where empresas.idempresa=%s and idsubtipo=1"""%a)
    rows = cur.fetchall()
    print rows
    for row in rows:
        x.append(i)
        i=i+1
        y.append(int(row[0]))
        empresa=str(row[1])
    grafica=lgn.line(y, thickness=5, xaxis=empresa, yaxis='Produccion en GW')
# Out:
# [(Decimal('5132'), 'CELEC-Electroguayas'), (Decimal('134324'), 'CELEC-Electroguayas'), (Decimal('39'), 'CELEC-Electroguayas'), (Decimal('68971'), 'CELEC-Electroguayas'), (Decimal('2847'), 'CELEC-Electroguayas'), (Decimal('15'), 'CELEC-Electroguayas'), (Decimal('2611'), 'CELEC-Electroguayas'), (Decimal('539038'), 'CELEC-Electroguayas'), (Decimal('1'), 'CELEC-Electroguayas'), (Decimal('2412'), 'CELEC-Electroguayas'), (Decimal('94'), 'CELEC-Electroguayas'), (Decimal('1374'), 'CELEC-Electroguayas'), (Decimal('52950'), 'CELEC-Electroguayas'), (Decimal('1'), 'CELEC-Electroguayas'), (Decimal('22195'), 'CELEC-Electroguayas')]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-607783ee6cae> in <module>()
#      13         empresa=str(row[1])
#      14     grafica=lgn.line(y, thickness=5, xaxis=empresa, yaxis='Produccion en GW')
# ---> 15     grafica.on()
#
# TypeError: on() takes exactly 3 arguments (1 given)
